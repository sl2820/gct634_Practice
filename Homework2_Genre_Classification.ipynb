# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/sl2820/gct634_Practice/blob/master/Homework2_Genre_Classification.ipynb)

# %% [markdown]
# #** Run Genre Classification on Google Colab**
#
# ---
#
# by Sangyoon
#
# Source Code from GCT634-2018 class ([Github Click Here](https://github.com/juhannam/gct634-2018/tree/master/hw2))

# %% [markdown]
# #### Before Begin,
# You need to have a main python file from class Github on your Google Drive.
# Also, there's feature extraction file from original Github source, but I ran the file on local computer and uploaded
# For the downloading and running the actual code, please modify according to your own address of Google Drive

# %% [markdown]
# ### Preliminery Code Running for Colab Environment

# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
from google.colab import drive
drive.mount('/content/drive')
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# Out:
# gpg: keybox '/tmp/tmpzjcz9eyc/pubring.gpg' created
# gpg: /tmp/tmpzjcz9eyc/trustdb.gpg: trustdb created
# gpg: key AD5F235DF639B041: public key "Launchpad PPA for Alessandro Strada" imported
# gpg: Total number processed: 1
# gpg:               imported: 1
# ...
# Mounted at /content/drive

# %%
# Install Keras (2.2.1 Version --> to use Keras-Contrib)
# !pip install keras
# !pip install -q keras==2.2.1
# !python -c 'import keras; print(keras.__version__)'

# Install Keras-Contrib
# !pip install git+https://www.github.com/keras-team/keras-contrib.git
# !pip install torch
# Out:
# ...
# tensorflow 1.11.0 has requirement keras-applications>=1.0.5, but you'll have keras-applications 1.0.4 which is incompatible.
# tensorflow 1.11.0 has requirement keras-preprocessing>=1.0.3, but you'll have keras-preprocessing 1.0.2 which is incompatible.
# Using TensorFlow backend.
# 2.2.1
# ...
#   Cloning https://www.github.com/keras-team/keras-contrib.git to /tmp/pip-req-build-Zkurgn
# ...
# done
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ICY3fo/wheels/11/27/c8/4ed56de7b55f4f61244e2dc6ef3cdbaff2692527a2ce6502ba
# Successfully built keras-contrib
# ...
#     100% |████████████████████████████████| 519.5MB 28kB/s
# ...

# %%
import os

# %%
label_path = '/drive/"My Drive"/Colab_Notebooks/Musical_Applications_of_Machine_Learning/gtzan/'
print(os.getcwd())
# Out:
# /content

# %%
with open('drive/My Drive/Colab_Notebooks/Musical_Applications_of_Machine_Learning/gtzan/train_filtered.txt') as f:
    train_list = f.read().splitlines()
    for line in train_list:
        y_train_dict[line] = line.split('/')[0]

# %%
# !python2 drive/"My Drive"/Colab_Notebooks/Musical_Applications_of_Machine_Learning/train_test_f.py
# Out:
# ['reggae', 'classical', 'country', 'jazz', 'metal', 'pop', 'disco', 'hiphop', 'rock', 'blues']
# (443, 128, 1287) (443,)
# drive/My Drive/Colab_Notebooks/Musical_Applications_of_Machine_Learning/train_test_f.py:228: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
#   epoch + 1, num_epochs, i + 1, len(train_loader), loss.data[0]))
# Epoch [1/50], Iter [10/88] loss : 2.5704
# Epoch [1/50], Iter [20/88] loss : 2.2956
# Epoch [1/50], Iter [30/88] loss : 1.5401
# Epoch [1/50], Iter [40/88] loss : 1.5258
# Epoch [1/50], Iter [50/88] loss : 1.7846
# Epoch [1/50], Iter [60/88] loss : 1.8805
# Epoch [1/50], Iter [70/88] loss : 2.8522
# Epoch [1/50], Iter [80/88] loss : 1.8331
# ...
